# %%
import pandas as pd

# %%
df = pd.read_excel('../data/raw/nsw_rentalbond_lodg_data/rental-bond-lodgement-data-february-2025.xlsx')
df.head()
# Out:
#   NSW Fair Trading\n\nResidential Rental Bond Lodgements\n\nFebruary  2025  \
# 0                                                NaN
# 1                                     Lodgement Date
# 2                                2025-02-24 00:00:00
# 3                                2025-02-28 00:00:00
# 4                                2025-02-27 00:00:00
#
#   Unnamed: 1     Unnamed: 2 Unnamed: 3   Unnamed: 4
# 0        NaN            NaN        NaN          NaN
# 1   Postcode  Dwelling Type   Bedrooms  Weekly Rent
# 2       2000              1          U          689
# 3       2000              F          0          690
# 4       2000              F          0         1000
